# %% [markdown]
# # 8.7 문서 군집화(Document Clustering)
# ## 8.7.1 문서 군집화 개념
# - 비슷한 텍스트 구성의 문서를 같은 카테고리 소속으로 분류
# - 비지도 학습 기반
#     - 문서의 결정 카테고리값이 없음
#     - 기존 클러스터링 방법 적용

# %% [markdown]
# ## 8.7.2 Opinion Review 데이터 세트를 이용한 문서 군집화 수행하기

# %% [markdown]
# * 데이터
#     - UCI 머신러닝 레파지토리 내 Opinion Review 데이터
#         - 51개 텍스트 파일(문서)
#         - 각 문서는 Tripadvisor(호텔), Edmunds.com(자동차), Amazon.com(전자제품) 사이트에서 가져온 리뷰
#         - 각 문서는 100개정도 문장 가짐
#         - 토픽 모델링에도 사용 가능
#         - http://archive.ics.uci.edu/ml/datasets/Opinosis+Opinion+%26frasl%3B+Review
#             - topics 폴더내 51개 파일 구성

# %%
# !ls -al
# Out:
# total 296328
# drwxr-xr-x  63 csg  staff      2016  3 20 15:49 .
# drwxr-xr-x  13 csg  staff       416  3 10 00:11 ..
# -rw-r--r--@  1 csg  staff      6148  3 20 15:48 .DS_Store
# drwxr-xr-x   4 csg  staff       128  3 20 14:39 .ipynb_checkpoints
# -rw-r--r--   1 csg  staff     60843  3 20 15:01 8.5 감성 분석_csg.ipynb
# -rw-r--r--   1 csg  staff      6527 10 27 18:28 8.6 토픽 모델링(Topic Modeling) - 20 뉴스그룹.ipynb
# -rw-r--r--   1 csg  staff     63748  3 20 15:49 8.7 문서 군집화 소개와 실습(Opinion Review 데이터 세트).ipynb
# drwxr-xr-x@  4 csg  staff       128  3 20 15:48 OpinosisDataset1.0
# -rw-r--r--   1 csg  staff      6553  3  6  2010 accuracy_garmin_nuvi_255W_gps.txt.data
# -rw-r--r--@  1 csg  staff      8399  3  6  2010 bathroom_bestwestern_hotel_sfo.txt.data
# -rw-r--r--   1 csg  staff      9753  3  6  2010 battery-life_amazon_kindle.txt.data
# -rw-r--r--   1 csg  staff      6368  3  6  2010 battery-life_ipod_nano_8gb.txt.data
# -rw-r--r--   1 csg  staff     35284  3  6  2010 battery-life_netbook_1005ha.txt.data
# -rw-r--r--   1 csg  staff     18035  3  6  2010 buttons_amazon_kindle.txt.data
# -rw-r--r--   1 csg  staff     14998  3  6  2010 comfort_honda_accord_2008.txt.data
# -rw-r--r--   1 csg  staff     10501  3  6  2010 comfort_toyota_camry_2007.txt.data
# -rw-r--r--   1 csg  staff     11929  3  6  2010 directions_garmin_nuvi_255W_gps.txt.data
# -rw-r--r--   1 csg  staff      5759  3  6  2010 display_garmin_nuvi_255W_gps.txt.data
# -rw-r--r--   1 csg  staff      8530  3  6  2010 eyesight-issues_amazon_kindle.txt.data
# -rw-r--r--   1 csg  staff      7096  3  6  2010 features_windows7.txt.data
# -rw-r--r--   1 csg  staff      7433  3  6  2010 fonts_amazon_kindle.txt.data
# -rw-r--r--   1 csg  staff     12263  3  6  2010 food_holiday_inn_london.txt.data
# -rw-r--r--   1 csg  staff      5723  3  6  2010 food_swissotel_chicago.txt.data
# -rw-r--r--   1 csg  staff     12762  3  6  2010 free_bestwestern_hotel_sfo.txt.data
# -rw-r--r--   1 csg  staff      9685  3  6  2010 gas_mileage_toyota_camry_2007.txt.data
# -rw-r--r--   1 csg  staff      8655  3  6  2010 interior_honda_accord_2008.txt.data
# -rw-r--r--   1 csg  staff     10092  3  6  2010 interior_toyota_camry_2007.txt.data
# -rw-r--r--   1 csg  staff     12085  3  6  2010 keyboard_netbook_1005ha.txt.data
# -rw-r--r--@  1 csg  staff  33556378  7 30  2014 labeledTrainData.tsv
# -rw-r--r--   1 csg  staff     30680  3  6  2010 location_bestwestern_hotel_sfo.txt.data
# -rw-r--r--   1 csg  staff     38017  3  6  2010 location_holiday_inn_london.txt.data
# -rw-r--r--   1 csg  staff     14061  3  6  2010 mileage_honda_accord_2008.txt.data
# -rw-r--r--   1 csg  staff      7216  3  6  2010 navigation_amazon_kindle.txt.data
# -rw-r--r--   1 csg  staff      9635  3  6  2010 parking_bestwestern_hotel_sfo.txt.data
# -rw-r--r--   1 csg  staff      4661  3  6  2010 performance_honda_accord_2008.txt.data
# -rw-r--r--   1 csg  staff      5780  3  6  2010 performance_netbook_1005ha.txt.data
# -rw-r--r--   1 csg  staff     10685  3  6  2010 price_amazon_kindle.txt.data
# -rw-r--r--   1 csg  staff     14876  3  6  2010 price_holiday_inn_london.txt.data
# -rw-r--r--   1 csg  staff      5898  3  6  2010 quality_toyota_camry_2007.txt.data
# -rw-r--r--   1 csg  staff     66569  3  6  2010 room_holiday_inn_london.txt.data
# -rw-r--r--   1 csg  staff     26262  3  6  2010 rooms_bestwestern_hotel_sfo.txt.data
# -rw-r--r--   1 csg  staff     15167  3  6  2010 rooms_swissotel_chicago.txt.data
# -rw-r--r--   1 csg  staff      7010  3  6  2010 satellite_garmin_nuvi_255W_gps.txt.data
# -rw-r--r--   1 csg  staff     11280  3  6  2010 screen_garmin_nuvi_255W_gps.txt.data
# -rw-r--r--   1 csg  staff      5854  3  6  2010 screen_ipod_nano_8gb.txt.data
# -rw-r--r--   1 csg  staff     19224  3  6  2010 screen_netbook_1005ha.txt.data
# -rw-r--r--   1 csg  staff      7361  3  6  2010 seats_honda_accord_2008.txt.data
# -rw-r--r--   1 csg  staff     14621  3  6  2010 service_bestwestern_hotel_sfo.txt.data
# -rw-r--r--   1 csg  staff     18060  3  6  2010 service_holiday_inn_london.txt.data
# -rw-r--r--   1 csg  staff     21415  3  6  2010 service_swissotel_hotel_chicago.txt.data
# -rw-r--r--   1 csg  staff      9979  3  6  2010 size_asus_netbook_1005ha.txt.data
# -rw-r--r--   1 csg  staff      8499  3  6  2010 sound_ipod_nano_8gb.txt.data
# -rw-r--r--   1 csg  staff      8335  3  6  2010 speed_garmin_nuvi_255W_gps.txt.data
# -rw-r--r--   1 csg  staff     11747  3  6  2010 speed_windows7.txt.data
# -rw-r--r--   1 csg  staff     31543  3  6  2010 staff_bestwestern_hotel_sfo.txt.data
# -rw-r--r--   1 csg  staff     18548  3  6  2010 staff_swissotel_chicago.txt.data
# -rw-r--r--   1 csg  staff  32724746  7 30  2014 testData.tsv
# -rw-r--r--   1 csg  staff     15275  3  6  2010 transmission_toyota_camry_2007.txt.data
# -rw-r--r--   1 csg  staff  67281491  7 30  2014 unlabeledTrainData.tsv
# -rw-r--r--   1 csg  staff      7058  3  6  2010 updates_garmin_nuvi_255W_gps.txt.data
# -rw-r--r--   1 csg  staff     19266  3  6  2010 video_ipod_nano_8gb.txt.data
# -rw-r--r--   1 csg  staff      9941  3  6  2010 voice_garmin_nuvi_255W_gps.txt.data
# drwxr-xr-x@  4 csg  staff       128  3 20 15:47 word2vec-nlp-tutorial

# %%
import pandas as pd
import glob ,os

# 컴퓨터에서 압축 파일을 풀어 놓은 디렉토리이니, 여러분의 디렉토리를 설정해 주십시요  
# path로 지정한 디렉토리 밑에 있는 모든 .data 파일들의 파일명을 리스트로 취합
# path = r'C:\Users\chkwon\Text\OpinosisDataset1.0\OpinosisDataset1.0\topics'                     
# all_files = glob.glob(os.path.join(path, "*.data"))  

path = '.'                     
file_list = os.path.join(path, "*.data")
all_files = glob.glob(file_list)   
#print(all_files)
#print(len(all_files))

# %%
# 개별 파일들의 파일명은 filename_list 리스트로 취합, 
# 개별 파일들의 파일내용은 DataFrame로딩 후 다시 string으로 변환하여 opinion_text 리스트로 취합 
filename_list = [] 
opinion_text = []
for file_ in all_files:
    # 개별 파일을 읽어서 DataFrame으로 생성 
    df = pd.read_table(file_, index_col=None, header=0,encoding='latin1')
    
    # 절대경로로 주어진 file 명을 가공. 만일 Linux에서 수행시에는 아래 \\를 / 변경. 맨 마지막 .data 확장자도 제거
    #filename_ = file_.split('\\')[-1]
    #filename = filename_.split('.')[0]
    filename = file_.replace("./", "").replace(".txt.data", "")
    #print(filename)
 
    #파일명 리스트와 파일내용 리스트에 파일명과 파일 내용을 추가. 
    filename_list.append(filename)
    opinion_text.append(df.to_string())
    
# 파일명 리스트와 파일내용 리스트를  DataFrame으로 생성
document_df = pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head() # filenaem으로 opinion의 text가 어떤 제품/서비스인지 알수 있음 -> 주제
# Out:
#                         filename  \
# 0     battery-life_ipod_nano_8gb
# 1  gas_mileage_toyota_camry_2007
# 2        room_holiday_inn_london
# 3    location_holiday_inn_london
# 4    staff_bestwestern_hotel_sfo
#
#                                         opinion_text
# 0           short battery life  I moved up from a...
# 1       Ride seems comfortable and gas mileage fa...
# 2      We arrived at 23,30 hours and they could n...
# 3       Great location for tube and we crammed in...
# 4                      Staff are friendly and hel...

# %%
document_df['opinion_text'][0]
# Out:
# "         short battery life  I moved up from an 8gb .\n0      I love this ipod except for the battery life .\n1                     long battery  scratch resistant\n2             Battery drains even if I don't use it .\n3    I only wonder why the battery seems to drain ...\n4    great in the car, light, portable, good quali...\n5   5G lies a more mature iPod, many steps wiser a...\n6   5GB and the better battery life rated for up t...\n7    battery, not dummie proof  I love the color o...\n8    Battery life isn't amazing, Definitely need t...\n9    The battery doesn't last a long time especial...\n10   doesn't take pictures, battery life  It's my ...\n11   Also, the battery life wasn't that long enoug...\n12   When you use the radio it uses a lot of batte...\n13   good quality  light  long battery  portable  ...\n14   scratches easily, short battery life  I purch...\n15   Price battery replacement  The iPod basically...\n16   I do not like it that I will have to get Appl...\n17   I think Apple's idea is that instead of repla...\n18   Make it inconvenient to replace the battery  ...\n19   The Pedometer feature seems accurate, but a b...\n20           short battery life  I like the product .\n21   good quality  scratch resistant  light  porta...\n22   Battery life is short  Received as a Christma...\n23   Battery life isn't great, but other than that...\n24   Battery Life  Product is exactly as advertise...\n25   shortened battery life, not kind to beginners...\n26     It is easy to use and has great battery life .\n27   Thought would have longer battery life before...\n28   The battery dies quickly and seems to die qui...\n29   Watching any videos drains the battery very q...\n30              Battery life is much better as well .\n31   Shorter battery life than old iPod, camera is...\n32   One thing I noticed that was not so good was ...\n33   the battery life  this was an awsome christma...\n34   this is my first ipod and its awsome the only...\n35      short battery life,have to keep changing it .\n36   the battery lasts 4 hours  great product for ...\n37   Battery life is excellent and the LCD display...\n38   Long battery life and easy directions make th...\n39   The battery dies faster than my previous 2nd ...\n40   My only complaint is that the battery doesn't...\n41      The battery is great and the screen as well .\n42   shipping charges  I bought this ipod as a bir...\n43   SHORT BATTERY LIFE,SCRATCHES EASY,  I DONT LI...\n44   Battery Life  I bought this ipod to replace m...\n45          The only bad thing is it's battery life .\n46   8 hours or less is a more realistic battery l...\n47  shoes if using vid cam for long time, it kills...\n48   battery life, becuase of all the features  I ...\n49   I have not found one thing other than the bat...\n50     So, the battery thing is not that big a deal .\n51   Overall, almost perfect just watch out or you...\n52   battery life, freezes up  I just got the 5th ...\n53   the pedometer is also very nice but seems lik...\n54    The new Nano has a very short battery life m...\n55   Very easy to use, love the pedometer, lightwe...\n56   Easy to use, Great sound, long battery life, ...\n57                    Battery life seems to be good .\n58   Scratches easily and the battery does not last .\n59     The battery is not as strong as it should be .\n60   But the battery is a little bit unpleased, bu...\n61                    Battery life is bad, real bad .\n62  Long battery life, Decent camera for such a sm...\n63       The video camera works great and the battery\n64     Then you find the battery only lasts about 1 .\n65   Long Battery Life, Sleek Compact, Easy To Set...\n66  My only complaint with this product is that th...\n67  I bought the nano as a replacement for an olde..."

# %%
from nltk.stem import WordNetLemmatizer
import nltk
import string

remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
print(string.punctuation)

lemmar = WordNetLemmatizer()

def LemTokens(tokens):
    return [lemmar.lemmatize(token) for token in tokens]

def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict))) # 소문자 변환, 특수문자 제거, 단어 토큰화, 단어 원형
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 문서 피쳐 벡터화: TF-IDF 
# tokenizer: LemNormalize 이용(LemNormalization 구현)
tfidf_vect = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english' , \
                             ngram_range=(1,2), min_df=0.05, max_df=0.85 )

#opinion_text 컬럼값으로 feature vectorization 수행 -> 개별 text에 대해 변환된 피처 벡터화 행렬 반환
feature_vect = tfidf_vect.fit_transform(document_df['opinion_text'])
print(feature_vect.shape) #(51, 2409)
# Out:
# /Users/csg/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# (51, 2409)

# %% [markdown]
# * 방법
#     - 데이터
#         - 문서별 텍스트가 TF-IDF 변환된 피쳐 벡터화 행렬 데이터
#         - 문서 유형: 전자제품(네비게이션, 아이팟, 킨들, 랩탑 컴퓨터...), 자동차, 호텔
#     - 군집화 기법: k-means
#       - 5개 중심(centroid)으로 시작
#       - 최대 반복 횟수: 10000

# %%
from sklearn.cluster import KMeans

# 5개 집합으로 군집화 수행. 예제를 위해 동일한 클러스터링 결과 도출용 random_state=0 //시드값 
km_cluster = KMeans(n_clusters=5, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_ # 군집의 라벨값
cluster_centers = km_cluster.cluster_centers_ # 중심별로 할당된 데이터 세트의 좌표값
print(cluster_centers.shape)
print(cluster_centers)
# Out:
# (5, 2409)
# [[0.         0.00686546 0.         ... 0.         0.         0.        ]
#  [0.02332668 0.         0.         ... 0.         0.         0.00208647]
#  [0.00425961 0.         0.         ... 0.         0.         0.        ]
#  [0.         0.00160316 0.00240348 ... 0.00306654 0.00328859 0.        ]
#  [0.01583394 0.         0.         ... 0.         0.         0.00644769]]

# %%
document_df['cluster_label'] = cluster_label
document_df.head() #filename(주제)과 cluster_label(군집화 결과)비교
# Out:
#                         filename  \
# 0     battery-life_ipod_nano_8gb
# 1  gas_mileage_toyota_camry_2007
# 2        room_holiday_inn_london
# 3    location_holiday_inn_london
# 4    staff_bestwestern_hotel_sfo
#
#                                         opinion_text  cluster_label
# 0           short battery life  I moved up from a...              1
# 1       Ride seems comfortable and gas mileage fa...              0
# 2      We arrived at 23,30 hours and they could n...              3
# 3       Great location for tube and we crammed in...              3
# 4                      Staff are friendly and hel...              3

# %%
document_df[document_df['cluster_label']==0].sort_values(by='filename') # 0번으로 군집화된 것중 filename 정렬하여 비교
# Out:
#                          filename  \
# 1   gas_mileage_toyota_camry_2007
# 35      mileage_honda_accord_2008
#
#                                          opinion_text  cluster_label
# 1        Ride seems comfortable and gas mileage fa...              0
# 35       It's quiet, get good gas mileage and look...              0

# %%
document_df[document_df['cluster_label']==1].sort_values(by='filename') # 1번으로 군집화된 것중 filename 정렬하여 비교
# Out:
#                        filename  \
# 9    battery-life_amazon_kindle
# 0    battery-life_ipod_nano_8gb
# 11  battery-life_netbook_1005ha
# 12      keyboard_netbook_1005ha
# 15   performance_netbook_1005ha
# 24          sound_ipod_nano_8gb
# 14          video_ipod_nano_8gb
#
#                                          opinion_text  cluster_label
# 9       After I plugged it in to my USB hub on my ...              1
# 0            short battery life  I moved up from a...              1
# 11      6GHz 533FSB cpu, glossy display, 3, Cell 2...              1
# 12      ,  I think the new keyboard rivals the gre...              1
# 15      The Eee Super Hybrid Engine utility lets u...              1
# 24      headphone jack i got a clear case for it a...              1
# 14      I bought the 8, gig Ipod Nano that has the...              1

# %%
document_df[document_df['cluster_label']==2].sort_values(by='filename') # 2번으로 군집화된 것중 filename 정렬하여 비교
# Out:
#                            filename  \
# 0     accuracy_garmin_nuvi_255W_gps
# 5             buttons_amazon_kindle
# 8   directions_garmin_nuvi_255W_gps
# 9      display_garmin_nuvi_255W_gps
# 10    eyesight-issues_amazon_kindle
# 11                features_windows7
# 12              fonts_amazon_kindle
# 23         navigation_amazon_kindle
# 33   satellite_garmin_nuvi_255W_gps
# 34      screen_garmin_nuvi_255W_gps
# 35             screen_ipod_nano_8gb
# 36            screen_netbook_1005ha
# 41         size_asus_netbook_1005ha
# 43       speed_garmin_nuvi_255W_gps
# 48     updates_garmin_nuvi_255W_gps
# 49              video_ipod_nano_8gb
# 50       voice_garmin_nuvi_255W_gps
#
#                                          opinion_text  cluster_label
# 0                          , and is very, very acc...              2
# 5       I thought it would be fitting to christen ...              2
# 8       You also get upscale features like spoken ...              2
# 9                3 quot  widescreen display was a ...              2
# 10      It feels as easy to read as the K1 but doe...              2
# 11      I had to uninstall anti, virus and selecte...              2
# 12       Being able to change the font sizes is aw...              2
# 23      In fact, the entire navigation structure h...              2
# 33                      It's fast to acquire satel...              2
# 34        It is easy to read and when touching the...              2
# 35      As always, the video screen is sharp and b...              2
# 36       Keep in mind that once you get in a room ...              2
# 41      A few other things I'd like to point out i...              2
# 43     Another feature on the 255w is a display of...              2
# 48     Another thing to consider was that I paid $...              2
# 49      I bought the 8, gig Ipod Nano that has the...              2
# 50       The voice prompts and maps are wonderful ...              2

# %%
document_df[document_df['cluster_label']==3].sort_values(by='filename') # 3번으로 군집화된 것중 filename 정렬하여 비교
# Out:
#                            filename  \
# 31   bathroom_bestwestern_hotel_sfo
# 17          food_holiday_inn_london
# 32           food_swissotel_chicago
# 49       free_bestwestern_hotel_sfo
# 39   location_bestwestern_hotel_sfo
# 3       location_holiday_inn_london
# 50    parking_bestwestern_hotel_sfo
# 41              price_amazon_kindle
# 28         price_holiday_inn_london
# 2           room_holiday_inn_london
# 46      rooms_bestwestern_hotel_sfo
# 30          rooms_swissotel_chicago
# 16    service_bestwestern_hotel_sfo
# 27       service_holiday_inn_london
# 13  service_swissotel_hotel_chicago
# 4       staff_bestwestern_hotel_sfo
# 20          staff_swissotel_chicago
#
#                                          opinion_text  cluster_label
# 31      The room was not overly big, but clean and...              3
# 17       The room was packed to capacity with queu...              3
# 32                 The food for our event was deli...              3
# 49      The wine reception is a great idea as it i...              3
# 39              Good Value good location ,  ideal ...              3
# 3        Great location for tube and we crammed in...              3
# 50      Parking was expensive but I think this is ...              3
# 41      If a case was included, as with the Kindle...              3
# 28      All in all, a normal chain hotel on a nice...              3
# 2       We arrived at 23,30 hours and they could n...              3
# 46      Great Location ,  Nice   Rooms ,  Helpless...              3
# 30      The Swissotel is one of our favorite hotel...              3
# 16       Both of us having worked in tourism for o...              3
# 27      not customer, oriented hotelvery low servi...              3
# 13       Mediocre room and service for a very extr...              3
# 4                       Staff are friendly and hel...              3
# 20       The staff at Swissotel were not particula...              3

# %%
document_df[document_df['cluster_label']==4].sort_values(by='filename') # 4번으로 군집화된 것중 filename 정렬하여 비교
# Out:
#                            filename  \
# 33    accuracy_garmin_nuvi_255W_gps
# 26            buttons_amazon_kindle
# 34  directions_garmin_nuvi_255W_gps
# 48     display_garmin_nuvi_255W_gps
# 36    eyesight-issues_amazon_kindle
# 21                features_windows7
# 44              fonts_amazon_kindle
# 38         navigation_amazon_kindle
# 10   satellite_garmin_nuvi_255W_gps
# 8       screen_garmin_nuvi_255W_gps
# 25             screen_ipod_nano_8gb
# 37            screen_netbook_1005ha
# 7          size_asus_netbook_1005ha
# 6        speed_garmin_nuvi_255W_gps
# 19     updates_garmin_nuvi_255W_gps
# 5        voice_garmin_nuvi_255W_gps
#
#                                          opinion_text  cluster_label
# 33                         , and is very, very acc...              4
# 26      I thought it would be fitting to christen ...              4
# 34      You also get upscale features like spoken ...              4
# 48               3 quot  widescreen display was a ...              4
# 36      It feels as easy to read as the K1 but doe...              4
# 21      I had to uninstall anti, virus and selecte...              4
# 44       Being able to change the font sizes is aw...              4
# 38      In fact, the entire navigation structure h...              4
# 10                      It's fast to acquire satel...              4
# 8         It is easy to read and when touching the...              4
# 25      As always, the video screen is sharp and b...              4
# 37       Keep in mind that once you get in a room ...              4
# 7       A few other things I'd like to point out i...              4
# 6      Another feature on the 255w is a display of...              4
# 19     Another thing to consider was that I paid $...              4
# 5        The voice prompts and maps are wonderful ...              4

# %%
from sklearn.cluster import KMeans

# 교재의 경우 군집 개수가 많아 세분화되어 군집화되었다 판단 -> 중심 개수를 낮춰 재군집화 
# 3개의 집합으로 군집화 
km_cluster = KMeans(n_clusters=3, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_


# 소속 클러스터를 cluster_label 컬럼으로 할당하고 cluster_label 값으로 정렬
document_df['cluster_label'] = cluster_label
#document_df.sort_values(by='cluster_label')

# %%
document_df[document_df['cluster_label']==0].sort_values(by='filename')
# Out:
#                            filename  \
# 33    accuracy_garmin_nuvi_255W_gps
# 9        battery-life_amazon_kindle
# 0        battery-life_ipod_nano_8gb
# 11      battery-life_netbook_1005ha
# 26            buttons_amazon_kindle
# 34  directions_garmin_nuvi_255W_gps
# 48     display_garmin_nuvi_255W_gps
# 36    eyesight-issues_amazon_kindle
# 21                features_windows7
# 44              fonts_amazon_kindle
# 12          keyboard_netbook_1005ha
# 38         navigation_amazon_kindle
# 15       performance_netbook_1005ha
# 41              price_amazon_kindle
# 10   satellite_garmin_nuvi_255W_gps
# 8       screen_garmin_nuvi_255W_gps
# 25             screen_ipod_nano_8gb
# 37            screen_netbook_1005ha
# 7          size_asus_netbook_1005ha
# 24              sound_ipod_nano_8gb
# 6        speed_garmin_nuvi_255W_gps
# 40                   speed_windows7
# 19     updates_garmin_nuvi_255W_gps
# 14              video_ipod_nano_8gb
# 5        voice_garmin_nuvi_255W_gps
#
#                                          opinion_text  cluster_label
# 33                         , and is very, very acc...              0
# 9       After I plugged it in to my USB hub on my ...              0
# 0            short battery life  I moved up from a...              0
# 11      6GHz 533FSB cpu, glossy display, 3, Cell 2...              0
# 26      I thought it would be fitting to christen ...              0
# 34      You also get upscale features like spoken ...              0
# 48               3 quot  widescreen display was a ...              0
# 36      It feels as easy to read as the K1 but doe...              0
# 21      I had to uninstall anti, virus and selecte...              0
# 44       Being able to change the font sizes is aw...              0
# 12      ,  I think the new keyboard rivals the gre...              0
# 38      In fact, the entire navigation structure h...              0
# 15      The Eee Super Hybrid Engine utility lets u...              0
# 41      If a case was included, as with the Kindle...              0
# 10                      It's fast to acquire satel...              0
# 8         It is easy to read and when touching the...              0
# 25      As always, the video screen is sharp and b...              0
# 37       Keep in mind that once you get in a room ...              0
# 7       A few other things I'd like to point out i...              0
# 24      headphone jack i got a clear case for it a...              0
# 6      Another feature on the 255w is a display of...              0
# 40      Windows 7 is quite simply faster, more sta...              0
# 19     Another thing to consider was that I paid $...              0
# 14      I bought the 8, gig Ipod Nano that has the...              0
# 5        The voice prompts and maps are wonderful ...              0

# %%
document_df[document_df['cluster_label']==1].sort_values(by='filename')
# Out:
#                           filename  \
# 18       comfort_honda_accord_2008
# 43       comfort_toyota_camry_2007
# 1    gas_mileage_toyota_camry_2007
# 45      interior_honda_accord_2008
# 22      interior_toyota_camry_2007
# 35       mileage_honda_accord_2008
# 47   performance_honda_accord_2008
# 42       quality_toyota_camry_2007
# 29         seats_honda_accord_2008
# 23  transmission_toyota_camry_2007
#
#                                          opinion_text  cluster_label
# 18       Drivers seat not comfortable, the car its...              1
# 43       Ride seems comfortable and gas mileage fa...              1
# 1        Ride seems comfortable and gas mileage fa...              1
# 45      I love the new body style and the interior...              1
# 22       First of all, the interior has way too ma...              1
# 35       It's quiet, get good gas mileage and look...              1
# 47     Very happy with my 08 Accord, performance i...              1
# 42      I previously owned a Toyota 4Runner which ...              1
# 29                   Front seats are very uncomfor...              1
# 23       After slowing down, transmission has to b...              1

# %%
document_df[document_df['cluster_label']==2].sort_values(by='filename')
# Out:
#                            filename  \
# 31   bathroom_bestwestern_hotel_sfo
# 17          food_holiday_inn_london
# 32           food_swissotel_chicago
# 49       free_bestwestern_hotel_sfo
# 39   location_bestwestern_hotel_sfo
# 3       location_holiday_inn_london
# 50    parking_bestwestern_hotel_sfo
# 28         price_holiday_inn_london
# 2           room_holiday_inn_london
# 46      rooms_bestwestern_hotel_sfo
# 30          rooms_swissotel_chicago
# 16    service_bestwestern_hotel_sfo
# 27       service_holiday_inn_london
# 13  service_swissotel_hotel_chicago
# 4       staff_bestwestern_hotel_sfo
# 20          staff_swissotel_chicago
#
#                                          opinion_text  cluster_label
# 31      The room was not overly big, but clean and...              2
# 17       The room was packed to capacity with queu...              2
# 32                 The food for our event was deli...              2
# 49      The wine reception is a great idea as it i...              2
# 39              Good Value good location ,  ideal ...              2
# 3        Great location for tube and we crammed in...              2
# 50      Parking was expensive but I think this is ...              2
# 28      All in all, a normal chain hotel on a nice...              2
# 2       We arrived at 23,30 hours and they could n...              2
# 46      Great Location ,  Nice   Rooms ,  Helpless...              2
# 30      The Swissotel is one of our favorite hotel...              2
# 16       Both of us having worked in tourism for o...              2
# 27      not customer, oriented hotelvery low servi...              2
# 13       Mediocre room and service for a very extr...              2
# 4                       Staff are friendly and hel...              2
# 20       The staff at Swissotel were not particula...              2

# %% [markdown]
# ## 8.7.3 군집(Cluster)별 핵심 단어 추출하기
# - 각 군집에 속한 문서는 핵심 단어를 주축으로 군집화 -> 군집의 핵심 단어 확인
# - KMeans 객체 cluster_centers_ 속성
#     - 각 군집을 구성하는 단어 피처가 군집의 중심(centroid)기준으로 얼마나 가깝게 위치한지 나타냄
#     - 행: 개별 군집
#     - 열: 개별 피처
#     - 각 배열값
#         - 개별 군집 내 상대 위치를 숫자 값으로 표현한 일종의 좌표값 (예) c[0,1] = 0번 군집에서 2번째 피처의 위치값
#         - 개별 중심과 얼마나 가까운지 상대값으로 나타냄, 0~1 값을 가짐 -> 1일 수록 중심에 가까움

# %%
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape :',cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape : (3, 2409)
# [[0.01819865 0.         0.         ... 0.         0.         0.00471073]
#  [0.         0.00170335 0.0025537  ... 0.0032582  0.00349413 0.        ]
#  [0.         0.00137309 0.         ... 0.         0.         0.        ]]

# %%
# 군집별 top n 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명들을 반환함. 
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features=10):
    cluster_details = {}
    
    # cluster_centers array 의 값이 큰 순으로 정렬된 index 값을 반환
    # 군집 중심점(centroid)별 할당된 word 피처들의 거리값이 큰 순으로 값을 구하기 위함.  
    centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:,::-1]
    
    #개별 군집별로 iteration하면서 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명 입력
    for cluster_num in range(clusters_num):
        
        # 개별 군집별 정보를 담을 데이터 초기화. 
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster'] = cluster_num
        
        # cluster_centers_.argsort()[:,::-1] 로 구한 index 를 이용하여 top n 피처 단어를 구함. 
        top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
        top_features = [ feature_names[ind] for ind in top_feature_indexes ]
        
        # top_feature_indexes를 이용해 해당 피처 단어의 중심 위치 상댓값 구함 
        top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()
        
        # cluster_details 딕셔너리 객체에 개별 군집별 핵심 단어와 중심위치 상대값, 그리고 해당 파일명 입력
        cluster_details[cluster_num]['top_features'] = top_features
        cluster_details[cluster_num]['top_features_value'] = top_feature_values
        filenames = cluster_data[cluster_data['cluster_label'] == cluster_num]['filename']
        filenames = filenames.values.tolist()
        cluster_details[cluster_num]['filenames'] = filenames
        
    return cluster_details

# %%
def print_cluster_details(cluster_details):
    for cluster_num, cluster_detail in cluster_details.items():
        print('####### Cluster {0}'.format(cluster_num))
        print('Top features:', cluster_detail['top_features'])
        print('--------------------------')
        #print('Top features value:', cluster_detail['top_features_value'])
        print('Reviews 파일명 개수 :',len(cluster_detail['filenames']))
        print('Reviews 파일명 :',cluster_detail['filenames']) #[:7]
        print('==================================================')

# %%
feature_names = tfidf_vect.get_feature_names()
#print("feature_names:", feature_names)

cluster_details = get_cluster_details(cluster_model=km_cluster, cluster_data=document_df,\
                                  feature_names=feature_names, clusters_num=3, top_n_features=10 )

print_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: ['screen', 'battery', 'life', 'battery life', 'keyboard', 'kindle', 'size', 'button', 'easy', 'voice']
# --------------------------
# Reviews 파일명 개수 : 25
# Reviews 파일명 : ['battery-life_ipod_nano_8gb', 'voice_garmin_nuvi_255W_gps', 'speed_garmin_nuvi_255W_gps', 'size_asus_netbook_1005ha', 'screen_garmin_nuvi_255W_gps', 'battery-life_amazon_kindle', 'satellite_garmin_nuvi_255W_gps', 'battery-life_netbook_1005ha', 'keyboard_netbook_1005ha', 'video_ipod_nano_8gb', 'performance_netbook_1005ha', 'updates_garmin_nuvi_255W_gps', 'features_windows7', 'sound_ipod_nano_8gb', 'screen_ipod_nano_8gb', 'buttons_amazon_kindle', 'accuracy_garmin_nuvi_255W_gps', 'directions_garmin_nuvi_255W_gps', 'eyesight-issues_amazon_kindle', 'screen_netbook_1005ha', 'navigation_amazon_kindle', 'speed_windows7', 'price_amazon_kindle', 'fonts_amazon_kindle', 'display_garmin_nuvi_255W_gps']
# ==================================================
# ####### Cluster 1
# Top features: ['interior', 'seat', 'mileage', 'comfortable', 'car', 'gas', 'transmission', 'gas mileage', 'ride', 'comfort']
# --------------------------
# Reviews 파일명 개수 : 10
# Reviews 파일명 : ['gas_mileage_toyota_camry_2007', 'comfort_honda_accord_2008', 'interior_toyota_camry_2007', 'transmission_toyota_camry_2007', 'seats_honda_accord_2008', 'mileage_honda_accord_2008', 'quality_toyota_camry_2007', 'comfort_toyota_camry_2007', 'interior_honda_accord_2008', 'performance_honda_accord_2008']
# ==================================================
# ####### Cluster 2
# Top features: ['room', 'hotel', 'service', 'location', 'staff', 'food', 'clean', 'bathroom', 'parking', 'room wa']
# --------------------------
# Reviews 파일명 개수 : 16
# Reviews 파일명 : ['room_holiday_inn_london', 'location_holiday_inn_london', 'staff_bestwestern_hotel_sfo', 'service_swissotel_hotel_chicago', 'service_bestwestern_hotel_sfo', 'food_holiday_inn_london', 'staff_swissotel_chicago', 'service_holiday_inn_london', 'price_holiday_inn_london', 'rooms_swissotel_chicago', 'bathroom_bestwestern_hotel_sfo', 'food_swissotel_chicago', 'location_bestwestern_hotel_sfo', 'rooms_bestwestern_hotel_sfo', 'free_bestwestern_hotel_sfo', 'parking_bestwestern_hotel_sfo']
# ==================================================
